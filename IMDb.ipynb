# %%
#Importing IMDb data

# %%
# !pip install --upgrade gdown
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.1.0
#     Uninstalling gdown-5.1.0:
#       Successfully uninstalled gdown-5.1.0
# ...

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 5.73MB/s]

# %%
#Insyalling Libraries
import pandas as pd,numpy as np

# %%
mdf=pd.read_csv('movies.csv')
mdf.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 50.8MB/s]

# %%
ddf=pd.read_csv('directors.csv')
ddf.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
#Movies Dataset

# %%
#In movie dataset, set Unnnamed column as Index

# %%
mdf=pd.read_csv('movies.csv',index_col=0)
mdf.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1465 entries, 0 to 4768
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1465 non-null   int64
#  1   budget        1465 non-null   int64
#  2   popularity    1465 non-null   int64
#  3   revenue       1465 non-null   int64
#  4   title         1465 non-null   object
#  5   vote_average  1465 non-null   float64
#  6   vote_count    1465 non-null   int64
#  7   director_id   1465 non-null   int64
#  8   year          1465 non-null   int64
#  9   month         1465 non-null   object
#  10  day           1465 non-null   object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 137.3+ KB

# %%
mdf.describe()
# Out:
#                  id        budget   popularity       revenue  vote_average  \
# count   1465.000000  1.465000e+03  1465.000000  1.465000e+03   1465.000000
# mean   45225.191126  4.802295e+07    30.855973  1.432539e+08      6.368191
# std     1189.096396  4.935541e+07    34.845214  2.064918e+08      0.818033
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44236.000000  1.400000e+07    11.000000  1.738013e+07      5.900000
# 50%    45022.000000  3.300000e+07    23.000000  7.578164e+07      6.400000
# 75%    45990.000000  6.600000e+07    41.000000  1.792469e+08      6.900000
# max    48395.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count  director_id         year
# count   1465.000000  1465.000000  1465.000000
# mean    1146.396587  5040.192491  2002.615017
# std     1578.077438   258.059631     8.680141
# min        1.000000  4762.000000  1976.000000
# 25%      216.000000  4845.000000  1998.000000
# ...

# %%
mdf.shape
# Out:
# (1465, 11)

# %%
#Director Dataset

# %%
ddf.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
ddf=pd.read_csv('directors.csv',index_col=0)
ddf.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
ddf.shape
# Out:
# (2349, 3)

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2349 entries, 0 to 2348
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   director_name  2349 non-null   object
#  1   id             2349 non-null   int64
#  2   gender         1724 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 73.4+ KB

# %%
ddf.describe()
# Out:
#                 id
# count  2349.000000
# mean   5936.000000
# std     678.242213
# min    4762.000000
# 25%    5349.000000
# 50%    5936.000000
# 75%    6523.000000
# max    7110.000000

# %%
#Merging Movies and Directors Dataset

# %%
mdf.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
ddf.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
df=mdf.merge(ddf,left_on='director_id',right_on='id',how='left')
df.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
df.shape
# Out:
# (1465, 14)

# %%
df.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
df.rename(columns={'id_x':'movie_id','id_y':'dir_id'},inplace=True)

# %%
df.head()
# Out:
#    movie_id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  dir_id gender
# 0         4762  2009   Dec  Thursday      James Cameron    4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski    4763   Male
# ...

# %%
df
# Out:
#       movie_id     budget  popularity     revenue  \
# 0        43597  237000000         150  2787965087
# 1        43598  300000000         139   961000000
# 2        43599  245000000         107   880674609
# 3        43600  250000000         112  1084939099
# 4        43602  258000000         115   890871626
# ...        ...        ...         ...         ...
# 1460     48363          0           3      321952
# 1461     48370      27000          19     3151130
# 1462     48375          0           7           0
# 1463     48376          0           3           0
# 1464     48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
#Number of directors
df['director_id'].nunique()
# Out:
# 199

# %%
#Number of Movies
df['movie_id'].nunique()
# Out:
# 1465

# %%
mdf.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
mdf['director_id'].nunique()
# Out:
# 199

# %%
ddf.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
ddf['id'].nunique()
# Out:
# 2349

# %%
#out of 2349 directors only 199 directors movies were listed in the Movies Dataset
#Now we are going to check whether the 199 directors in the movie data set is captured in the directors dataset

# %%
np.all(mdf['director_id'].isin(ddf['id']))
# Out:
# True

# %%
#Now its clear that all the directors in the movies dataset is captured in Directors dataset

# %%
#Which means 199 directors directed 1465 movies
df[['director_id','director_name']].value_counts()
# Out:
# director_id  director_name
# 4799         Steven Spielberg      26
# 4809         Martin Scorsese       19
# 5087         Clint Eastwood        19
# 5457         Woody Allen           18
# 4779         Ridley Scott          16
#                                    ..
# 5105         Tim Hill               5
# 4849         Jonathan Liebesman     5
# 5096         Roman Polanski         5
# 5088         Larry Charles          5
# 6204         Nicole Holofcener      5
# Name: count, Length: 199, dtype: int64

# %%
#dropping duplicate column
df
# Out:
#       movie_id     budget  popularity     revenue  \
# 0        43597  237000000         150  2787965087
# 1        43598  300000000         139   961000000
# 2        43599  245000000         107   880674609
# 3        43600  250000000         112  1084939099
# 4        43602  258000000         115   890871626
# ...        ...        ...         ...         ...
# 1460     48363          0           3      321952
# 1461     48370      27000          19     3151130
# 1462     48375          0           7           0
# 1463     48376          0           3           0
# 1464     48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
df.drop(['dir_id'],axis=1,inplace=True)

# %%
df
# Out:
#       movie_id     budget  popularity     revenue  \
# 0        43597  237000000         150  2787965087
# 1        43598  300000000         139   961000000
# 2        43599  245000000         107   880674609
# 3        43600  250000000         112  1084939099
# 4        43602  258000000         115   890871626
# ...        ...        ...         ...         ...
# 1460     48363          0           3      321952
# 1461     48370      27000          19     3151130
# 1462     48375          0           7           0
# 1463     48376          0           3           0
# 1464     48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
#We can find number of movies released per year.
#Find highest budget movies in a year using both budget and year.

#Do you think we can find the most productive directors?
#Which directors produce high budget films?
#Highest and lowest rated movies for every month in a particular year?

# %%
#Top 10 most popular movies, using popularity.
Top_10_movies=mdf.sort_values('popularity',ascending=False).head(10)
Top_10_movies
# Out:
#         id     budget  popularity     revenue  \
# 95   43692  165000000         724   675120017
# 127  43724  150000000         434   378858340
# 199  43796  140000000         271   655011224
# 200  43797  125000000         206   752100229
# 65   43662  185000000         187  1004558444
# 270  43867  108000000         167   630161890
# 96   43693  160000000         167   825532764
# 9    43606  250000000         155   873260194
# 0    43597  237000000         150  2787965087
# 662  44259   63000000         146   100853753
#
#                                                  title  vote_average  \
# 95                                        Interstellar           8.1
# 127                                 Mad Max: Fury Road           7.2
# 199  Pirates of the Caribbean: The Curse of the Bla...           7.5
# 200              The Hunger Games: Mockingjay - Part 1           6.6
# 65                                     The Dark Knight           8.2
# ...

# %%
df.head()
# Out:
#    movie_id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name gender
# 0         4762  2009   Dec  Thursday      James Cameron   Male
# 1         4763  2007   May  Saturday     Gore Verbinski   Male
# 2         4764  2015   Oct    Monday         Sam Mendes   Male
# ...

# %%
#converting budget and revenue column in Millions (USD)
df[['budget','revenue']]=(df[['budget','revenue']]/1000000).round(2)
df.head()
# Out:
#    movie_id  budget  popularity  revenue  \
# 0     43597   237.0         150  2787.97
# 1     43598   300.0         139   961.00
# 2     43599   245.0         107   880.67
# 3     43600   250.0         112  1084.94
# 4     43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name gender
# 0         4762  2009   Dec  Thursday      James Cameron   Male
# 1         4763  2007   May  Saturday     Gore Verbinski   Male
# 2         4764  2015   Oct    Monday         Sam Mendes   Male
# ...

# %%
#Find the highest rated movies, using vote_average.
#Movies Rating >7

# %%
df.loc[df['vote_average']>7]
# Out:
#       movie_id  budget  popularity  revenue  \
# 0        43597  237.00         150  2787.97
# 3        43600  250.00         112  1084.94
# 14       43616  250.00         120   956.02
# 16       43619  250.00          94   958.40
# 19       43622  200.00         100  1845.03
# ...        ...     ...         ...      ...
# 1456     48321    0.01          20     7.00
# 1457     48323    0.00           5     0.00
# 1458     48335    0.06          27     3.22
# 1460     48363    0.00           3     0.32
# 1461     48370    0.03          19     3.15
#
#                                           title  vote_average  vote_count  \
# 0                                        Avatar           7.2       11800
# 3                         The Dark Knight Rises           7.6        9106
# 14    The Hobbit: The Battle of the Five Armies           7.1        4760
# 16          The Hobbit: The Desolation of Smaug           7.6        4524
# ...

# %%
df.loc[df['vote_average']>7][['title','director_name']]
# Out:
#                                           title      director_name
# 0                                        Avatar      James Cameron
# 3                         The Dark Knight Rises  Christopher Nolan
# 14    The Hobbit: The Battle of the Five Armies      Peter Jackson
# 16          The Hobbit: The Desolation of Smaug      Peter Jackson
# 19                                      Titanic      James Cameron
# ...                                         ...                ...
# 1456                                 Eraserhead        David Lynch
# 1457                                 The Mighty      Peter Chelsom
# 1458                                         Pi   Darren Aronofsky
# 1460                             The Last Waltz    Martin Scorsese
# 1461                                     Clerks        Kevin Smith
#
# [301 rows x 2 columns]

# %%
#Filter highly rated movie after 2014

# %%
df.loc[(df['vote_average']>7) & (df['year']>2014)]
# Out:
#       movie_id  budget  popularity  revenue                    title  \
# 30       43641   190.0         102  1506.25                Furious 7
# 78       43724   150.0         434   378.86       Mad Max: Fury Road
# 106      43773   135.0         100   532.95             The Revenant
# 162      43867   108.0         167   630.16              The Martian
# 312      44128    75.0          48   108.15  The Man from U.N.C.L.E.
# 394      44281    44.0          68   155.76        The Hateful Eight
# 625      44770    35.0          53   194.56               The Intern
# 635      44784    40.0          48   165.48          Bridge of Spies
# 808      45194    30.0          65    91.71                 Southpaw
# 833      45293    28.0          61   201.63   Straight Outta Compton
# 839      45301    28.0          57   133.35            The Big Short
# 1344     47181     5.0          22    24.80                     Race
#
#       vote_average  vote_count  director_id  year month        day  \
# ...

# %%
df.loc[(df['vote_average']>7)&(df['year']>=2015)][['vote_average','year','title','director_name']]
# Out:
#       vote_average  year                    title                director_name
# 30             7.3  2015                Furious 7                    James Wan
# 78             7.2  2015       Mad Max: Fury Road                George Miller
# 106            7.3  2015             The Revenant  Alejandro González Iñárritu
# 162            7.6  2015              The Martian                 Ridley Scott
# 312            7.1  2015  The Man from U.N.C.L.E.                  Guy Ritchie
# 394            7.6  2015        The Hateful Eight            Quentin Tarantino
# 625            7.1  2015               The Intern                 Nancy Meyers
# 635            7.2  2015          Bridge of Spies             Steven Spielberg
# 808            7.3  2015                 Southpaw                Antoine Fuqua
# 833            7.7  2015   Straight Outta Compton                 F. Gary Gray
# 839            7.3  2015            The Big Short                   Adam McKay
# ...

# %%
#Movies released on Friday or Sunday
df[(df['day']=='Friday')|(df['day']=='Sunday')]
# Out:
#       movie_id  budget  popularity  revenue  \
# 22       43627  200.00          35   783.77
# 25       43632  150.00          21   836.30
# 53       43672  175.00          44   264.22
# 61       43696   38.00           6   207.28
# 65       43701  160.00          21   181.67
# ...        ...     ...         ...      ...
# 1458     48335    0.06          27     3.22
# 1459     48359    0.00           2     0.00
# 1462     48375    0.00           7     0.00
# 1463     48376    0.00           3     0.00
# 1464     48395    0.22          14     2.04
#
#                                     title  vote_average  vote_count  \
# 22                           Spider-Man 2           6.7        4321
# 25    Transformers: Revenge of the Fallen           6.0        3138
# 53                             Waterworld           5.9         992
# 61               The Fast and the Furious           6.6        3428
# 65                               Poseidon           5.5         583
# ...

# %%
#Top 5 most Popular movies
df.sort_values('popularity',ascending=False).head(1)
# Out:
#     movie_id  budget  popularity  revenue         title  vote_average  \
# 58     43692   165.0         724   675.12  Interstellar           8.1
#
#     vote_count  director_id  year month        day      director_name gender
# 58       10867         4765  2014   Nov  Wednesday  Christopher Nolan   Male

# %%
#Movies directed by specific director
df[df['director_name']=='Christopher Nolan'][['title','revenue']]
# Out:
#                       title  revenue
# 3     The Dark Knight Rises  1084.94
# 45          The Dark Knight  1004.56
# 58             Interstellar   675.12
# 59                Inception   825.53
# 74            Batman Begins   374.22
# 565                Insomnia   113.71
# 641            The Prestige   109.68
# 1341                Memento    39.72

# %%
#apply
def encode(df):
  if df=="Male":
    return 1
  else:
    return 0

# %%
df
# Out:
#       movie_id  budget  popularity  revenue  \
# 0        43597  237.00         150  2787.97
# 1        43598  300.00         139   961.00
# 2        43599  245.00         107   880.67
# 3        43600  250.00         112  1084.94
# 4        43602  258.00         115   890.87
# ...        ...     ...         ...      ...
# 1460     48363    0.00           3     0.32
# 1461     48370    0.03          19     3.15
# 1462     48375    0.00           7     0.00
# 1463     48376    0.00           3     0.00
# 1464     48395    0.22          14     2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
[df['gender'].apply(encode)]
# Out:
# [0       1
#  1       1
#  2       1
#  3       1
#  4       1
#         ..
#  1460    1
#  1461    1
#  1462    1
#  1463    1
#  1464    0
#  Name: gender, Length: 1465, dtype: int64]
